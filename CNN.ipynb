# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid

import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
# Convert MNIST Image Files into a Tensor of 4-Dimensions (# of images, Height, Width, Color Channels)
transform = transforms.ToTensor()

# %%
# Train Data
train_data = datasets.MNIST(root='/Users/aakashagarwal/PycharmProjects/pytorch/cnn_data', train=True, download=True, transform=transform)# Train Data
train_data = datasets.MNIST(root='/Users/aakashagarwal/PycharmProjects/pytorch/cnn_data', train=True, download=True, transform=transform)

# %%
test_data = datasets.MNIST(root='/Users/aakashagarwal/PycharmProjects/pytorch/cnn_data', train=False, download=True, transform=transform)
